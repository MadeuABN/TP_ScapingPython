# %%
import os
os.getcwd()
# Out:
# '/Users/madeu'

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url= "http://feeds.bbci.co.uk/news/rss.xml"

# %%
reponse=requests.get(url)
soup=BeautifulSoup(reponse.text,"html.parser")
soup
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <?xml-stylesheet title="XSL_formatting" type="text/xsl" href="/shared/bsp/xsl/rss/nolsol.xsl"?>
# <rss version="2.0" xmlns:atom="http://www.w3.org/2005/Atom" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:media="http://search.yahoo.com/mrss/">
# <channel>
# <title><![CDATA[BBC News - Home]]></title>
# <description><![CDATA[BBC News - Home]]></description>
# <link/>https://www.bbc.co.uk/news/
#         <image/>
# <url>https://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif</url>
# <title>BBC News - Home</title>
# <link/>https://www.bbc.co.uk/news/
#
#         <generator>RSS for Node</generator>
# <lastbuilddate>Sun, 13 Mar 2022 11:37:42 GMT</lastbuilddate>
# <copyright><![CDATA[Copyright: (C) British Broadcasting Corporation, see http://news.bbc.co.uk/2/hi/help/rss/4498287.stm for terms and conditions of reuse.]]></copyright>
# <language><![CDATA[en-gb]]></language>
# ...

# %%
items=soup.findAll('item')

# %%
items
# Out:
# [<item>
#  <title><![CDATA[Ukraine war: UK households offered £350 a month for hosting refugees]]></title>
#  <description><![CDATA[Households are encouraged to join the "national effort", but critics say the plan falls short.]]></description>
#  <link/>https://www.bbc.co.uk/news/uk-60724111?at_medium=RSS&amp;at_campaign=KARANGA
#              <guid ispermalink="false">https://www.bbc.co.uk/news/uk-60724111</guid>
#  <pubdate>Sun, 13 Mar 2022 11:05:31 GMT</pubdate>
#  </item>,
#  <item>
#  <title><![CDATA[War in Ukraine: Uni to uniform - Ukraine's new teenage army recruits]]></title>
#  <description><![CDATA[Young volunteers swap their studies for assault rifles as they prepare to defend Kyiv from Russian forces.]]></description>
#  <link/>https://www.bbc.co.uk/news/world-europe-60724560?at_medium=RSS&amp;at_campaign=KARANGA
#              <guid ispermalink="false">https://www.bbc.co.uk/news/world-europe-60724560</guid>
#  <pubdate>Sat, 12 Mar 2022 23:57:22 GMT</pubdate>
#  </item>,
# ...

# %%
item=items[0]

# %%
item.description.text
# Out:
# 'Households are encouraged to join the "national effort", but critics say the plan falls short.'

# %%
news_items=[]

# %%
for i in items:
    news_i={}
    news_i['title']=i.title.text
    news_i['description']=i.description.text
    news_i['pubdate']=i.pubdate.text
    news_items.append(news_i)

# %%
 news_items
# Out:
# [{'title': 'Ukraine war: UK households offered £350 a month for hosting refugees',
#   'description': 'Households are encouraged to join the "national effort", but critics say the plan falls short.',
#   'pubdate': 'Sun, 13 Mar 2022 11:05:31 GMT'},
#  {'title': "War in Ukraine: Uni to uniform - Ukraine's new teenage army recruits",
#   'description': 'Young volunteers swap their studies for assault rifles as they prepare to defend Kyiv from Russian forces.',
#   'pubdate': 'Sat, 12 Mar 2022 23:57:22 GMT'},
#  {'title': 'War in Ukraine: Russian forces accused of abducting second mayor',
#   'description': 'The news comes as Ukraine says Russia is trying to create "pseudo-republics" to break up the country.',
#   'pubdate': 'Sun, 13 Mar 2022 11:29:12 GMT'},
#  {'title': 'Irbil attack: Missiles from Iran hit northern Iraqi city, US says',
#   'description': 'The missiles damaged buildings near the US consulate in Irbil, but no casualties have been reported.',
# ...

# %%
df=pd.DataFrame(news_items,columns=['title','description','pubdate'])

# %%
df.head(20)
# Out:
#                                                 title  \
# 0   Ukraine war: UK households offered £350 a mont...
# 1   War in Ukraine: Uni to uniform - Ukraine's new...
# 2   War in Ukraine: Russian forces accused of abdu...
# 3   Irbil attack: Missiles from Iran hit northern ...
# 4   Scotland and Wales bid to be refugee super spo...
# 5   Bafta Awards 2022: Stars prepare to return to ...
# 6   Boss accused of defrauding blind workers' pens...
# 7   Ukraine: Ireland's 'priority is humanitarian' ...
# 8   Roman Abramovich: Rabbi investigated over Port...
# 9   Naomi Osaka in tears after being heckled mid-game
# 10  Liverpool schools: The parents tackling admiss...
# 11            Saudi Arabia executes 81 men in one day
# 12  Michael Conlan 'all good' after Leigh Wood ret...
# 13  Russia faces brain drain as thousands flee abroad
# 14  Indian evacuee: The kindness of Ukrainians sav...
# 15  Russia sanctions: How the measures have change...
# ...

# %%
df.to_csv('webscapping_Madavane.csv',index=False,encoding='utf-8')
